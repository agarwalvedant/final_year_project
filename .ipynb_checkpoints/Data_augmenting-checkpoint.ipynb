# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (4.32.1)
# Requirement already satisfied: filelock in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from transformers) (0.3.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from requests->transformers) (2023.11.17)

# %%
pip install --upgrade openai
# Out:
# Collecting openai
#   Obtaining dependency information for openai from https://files.pythonhosted.org/packages/ee/49/7baf2537d7eedb162c8212e973bd69fe7233b463118e469bdb1bb07506f6/openai-1.50.2-py3-none-any.whl.metadata
#   Downloading openai-1.50.2-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from openai) (3.5.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Obtaining dependency information for distro<2,>=1.7.0 from https://files.pythonhosted.org/packages/12/b3/231ffd4ab1fc9d679809f356cebee130ac7daa00d6d6f3206dd4fd137e9e/distro-1.9.0-py3-none-any.whl.metadata
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Obtaining dependency information for httpx<1,>=0.23.0 from https://files.pythonhosted.org/packages/56/95/9377bcb415797e44274b51d46e3249eba641711cf3348050f76ee7b15ffc/httpx-0.27.2-py3-none-any.whl.metadata
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Obtaining dependency information for jiter<1,>=0.4.0 from https://files.pythonhosted.org/packages/03/eb/2308fa5f5c14c97c4c7720fef9465f1fa0771826cddb4eec9866bdd88846/jiter-0.5.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading jiter-0.5.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.6 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from openai) (1.10.8)
# Requirement already satisfied: sniffio in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from openai) (1.2.0)
# Requirement already satisfied: tqdm>4 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from openai) (4.65.0)
# Collecting typing-extensions<5,>=4.11 (from openai)
#   Obtaining dependency information for typing-extensions<5,>=4.11 from https://files.pythonhosted.org/packages/26/9f/ad63fc0248c5379346306f8668cda6e2e2e9c95e01216d2b8ffd9ff037d0/typing_extensions-4.12.2-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: idna>=2.8 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2023.11.17)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Obtaining dependency information for httpcore==1.* from https://files.pythonhosted.org/packages/78/d4/e5d7e4f2174f8a4d63c8897d79eb8fe2503f7ecc03282fee1fa2719c2704/httpcore-1.0.5-py3-none-any.whl.metadata
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Obtaining dependency information for h11<0.15,>=0.13 from https://files.pythonhosted.org/packages/95/04/ff642e65ad6b90db43e668d70ffb6736436c7ce41fcc549f4e9472234127/h11-0.14.0-py3-none-any.whl.metadata
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Downloading openai-1.50.2-py3-none-any.whl (382 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.0/383.0 kB 979.5 kB/s eta 0:00:00a 0:00:01
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Downloading jiter-0.5.0-cp311-cp311-macosx_11_0_arm64.whl (299 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.3/299.3 kB 1.1 MB/s eta 0:00:0000:0100:01
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: typing-extensions, jiter, h11, distro, httpcore, httpx, openai
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
# Successfully installed distro-1.9.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 jiter-0.5.0 openai-1.50.2 typing-extensions-4.12.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install backoff
# Out:
# Collecting backoff
#   Obtaining dependency information for backoff from https://files.pythonhosted.org/packages/df/73/b6e24bd22e6720ca8ee9a85a0c4a2971af8497d8f3193fa05390cbd46e09/backoff-2.2.1-py3-none-any.whl.metadata
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Installing collected packages: backoff
# Successfully installed backoff-2.2.1

# %%
# !pip install tiktoken
# %pip install --upgrade tiktoken
# Out:
# Collecting tiktoken
#   Obtaining dependency information for tiktoken from https://files.pythonhosted.org/packages/30/ef/e07dbfcb2f85c84abaa1b035a9279575a8da0236305491dc22ae099327f7/tiktoken-0.7.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading tiktoken-0.7.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: regex>=2022.1.18 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from tiktoken) (2022.7.9)
# Requirement already satisfied: requests>=2.26.0 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (2023.11.17)
# Downloading tiktoken-0.7.0-cp311-cp311-macosx_11_0_arm64.whl (907 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 907.0/907.0 kB 1.6 MB/s eta 0:00:00a 0:00:01m
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.7.0
# Requirement already satisfied: tiktoken in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (0.7.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from tiktoken) (2022.7.9)
# Requirement already satisfied: requests>=2.26.0 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vedantagarwal/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (2023.11.17)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import GPT2Tokenizer, OpenAIGPTTokenizer, GPT2TokenizerFast
import tiktoken

# %%
import pandas as pd
import json
import csv
import numpy as np

import os
import time

# %%
import openai

# %%
openai.api_key = "XXX"

# %%
os.environ['OPENAI_API_KEY'] = 'XXX'

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Setting the base path
# base_path =  "/content/gdrive/MyDrive/Muskan_Project"

# %%
# os.chdir(base_path)

# %%
df = pd.read_csv("dataset_wellnessdimensions.csv")
df
# Out:
#       Unnamed: 0                                               Text  Aspect  \
# 0              0  Once it happens there is no going back and you...       4
# 1              1  Now i am filled with guilt and stuck feeling l...       4
# 2              2  And i got home and the voices returned and kep...       4
# 3              3  Before her I survived since shit, sexual assau...       1
# 4              4  I feel like there are only three things that y...       1
# ...          ...                                                ...     ...
# 3087        3087  I am mature student in, Toxic class mates, bas...       4
# 3088        3088               i want to be dead, everyone hates me       4
# 3089        3089  I believe that I am selfish and feel because I...       4
# 3090        3090  i dont wanna die, i want to live to be happy t...       4
# 3091        3091  Fuck I really hate myself, I get upset over th...       4
#
#                                        Explanations
# 0                            empty void of darkness
# 1     filled with guilt and stuck feeling like crap
# 2                                     piece of shit
# 3                                   sexual assaults
# 4                           ugly, dumb, and useless
# ...                                             ...
# 3087                                    hate myself
# 3088                              everyone hates me
# 3089                                        selfish
# 3090                                    hate myself
# 3091                                    hate myself
#
# [3092 rows x 4 columns]

# %%
df['Aspect'].value_counts()
# Out:
# Aspect
# 3    1139
# 1     740
# 4     621
# 2     592
# Name: count, dtype: int64

# %%
class_counts = df['Aspect'].value_counts().reset_index()
class_counts.columns = ["class", "count"]
class_counts
# Out:
#    class  count
# 0      3   1139
# 1      1    740
# 2      4    621
# 3      2    592

# %%
c1=class_counts.loc[class_counts['class'] == 1, 'count']
c2=class_counts.loc[class_counts['class'] == 2, 'count']
c3=class_counts.loc[class_counts['class'] == 3, 'count']
c4=class_counts.loc[class_counts['class'] == 4, 'count']

c1=int(c1)
c2=int(c2)
c3=int(c3)
c4=int(c4)
# Out:
# /var/folders/ct/kntzy8pd1gx_5fs6lpgjjm740000gn/T/ipykernel_83510/2204570741.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   c1=int(c1)
# /var/folders/ct/kntzy8pd1gx_5fs6lpgjjm740000gn/T/ipykernel_83510/2204570741.py:7: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   c2=int(c2)
# /var/folders/ct/kntzy8pd1gx_5fs6lpgjjm740000gn/T/ipykernel_83510/2204570741.py:8: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   c3=int(c3)
# /var/folders/ct/kntzy8pd1gx_5fs6lpgjjm740000gn/T/ipykernel_83510/2204570741.py:9: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   c4=int(c4)

# %% [markdown]
# Generating Text based on given Class

# %%
def generate_text(prompt, class_label):

    model_engine = "gpt-3.5-turbo"  
    # model_engine = "gpt-3.5-turbo-0301"

    model_prompt = (f"Considering the given topic, generate similar text to the given text.\nTopic: {class_label}\nText: {prompt}####\n\nSimilar text:")  # Set up the GPT prompt

    time.sleep(0.01)
    response = openai.ChatCompletion.create(
        model=model_engine,
        messages=[{"role": "user", "content": model_prompt}],
        temperature = 0.5,
        stop="####"
    )

    print(prompt)
    print(response['choices'][0]['message']['content'])
    
    return response['choices'][0]['message']['content']

# %% [markdown]
# Generating Explanation based on given augmented text

# %%
def generate_explanation(ori_text,ori_exp,aug_text):
        
    model_engine = "gpt-3.5-turbo" 
 
    model_prompt = (f"Consider the examples and generate a very short explanation of the given text.\n\n \
    text: i want to be dead, everyone hates me\nexplanation: everyone hates me\n \
    text: If reincarnation is a real thing I was a selfish person that wanted the world now im stuck\nexplanation: selfish person \n \
    text: I can't even talk to anyone anymore because everyone walks around with those goddamn airpods and it makes everyone so unapproachable\nexplanation: makes everyone so unapproachabley\n \
    text: I have no motivation nor intention to progress in my life\nexplanation: no motivation \n \
    text: What if my parents die? What do I do? I don't know, I feel hideously ugly\nexplanation: feel hideously ugly\n \
    text: {ori_text}\nexplanation: {ori_exp}\n\n \
    text: {aug_text}\nexplanation:")  
    # print(model_prompt)

    time.sleep(0.01)
    response = openai.ChatCompletion.create(
        model=model_engine,
        messages=[{"role": "user", "content": model_prompt}],
        temperature=0.2
        # presence_penalty=-1.5
    )
    print(ori_exp)
    print(response['choices'][0]['message']['content'])
    print("\n\n")
    return response['choices'][0]['message']['content']

# %%
# Declare global lists to store results

augmented_data1 =[]
augmented_data2 =[]
augmented_data_labels =[]
original_data = []
original_explain = []

# %%
def appending_data(text, label, explanation, original, ori_exp):

  augmented_data1.append(text)
  augmented_data_labels.append(label)
  augmented_data2.append(explanation)
  original_data.append(original) 
  original_explain.append(ori_exp)

# %%
# Call API to generate text

class_1=0
class_2=0
class_3=0
class_4=0
max_records=1139
i=0

# df = df.reset_index()  # make sure indexes pair with number of rows
for index, row in df.iterrows():

  original_text = row['Text']
  original_exp = row['Explanations']
  class_label = row['Aspect']

  # original_token_ratio = calc_token_ratio(original_text, original_exp)

  print(i)
  i+=1

  if(class_label==1 and c1+class_1 < max_records):
    augmented_text = generate_text(original_text, "Physical Aspect")
    augmented_exp = generate_explanation(original_text, original_exp, augmented_text)
    appending_data(augmented_text, class_label, augmented_exp, original_text, original_exp)
    class_1+=1
    
  elif (class_label==2 and c2+class_2 < max_records):
    augmented_text = generate_text(original_text, "Intellectual and Vocational Aspect")
    augmented_exp = generate_explanation(original_text, original_exp, augmented_text)
    appending_data(augmented_text, class_label, augmented_exp, original_text, original_exp)
    class_2+=1

  elif (class_label==3 and c3+class_3 < max_records): 
    augmented_text = generate_text(original_text, "Social Aspect")
    augmented_exp = generate_explanation(original_text, original_exp, augmented_text)
    appending_data(augmented_text, class_label, augmented_exp, original_text, original_exp)
    class_3+=1

  elif (class_label==4 and c4+class_4 < max_records):
    augmented_text = generate_text(original_text, "Spiritual and Emotional Aspect")
    augmented_exp = generate_explanation(original_text, original_exp, augmented_text)
    appending_data(augmented_text, class_label, augmented_exp, original_text, original_exp)
    class_4+=1
# Out:
# 0
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[18], line 41
#      38   class_3+=1
#      40 elif (class_label==4 and c4+class_4 < max_records):
# ---> 41   augmented_text = generate_text(original_text, "Spiritual and Emotional Aspect")
#      42   augmented_exp = generate_explanation(original_text, original_exp, augmented_text)
#      43   appending_data(augmented_text, class_label, augmented_exp, original_text, original_exp)
#
# Cell In[14], line 9, in generate_text(prompt, class_label)
#       6 model_prompt = (f"Considering the given topic, generate similar text to the given text.\nTopic: {class_label}\nText: {prompt}####\n\nSimilar text:")  # Set up the GPT prompt
#       8 time.sleep(0.01)
# ----> 9 response = openai.ChatCompletion.create(
#      10     model=model_engine,
#      11     messages=[{"role": "user", "content": model_prompt}],
#      12     temperature = 0.5,
#      13     stop="####"
#      14 )
#      16 print(prompt)
#      17 print(response['choices'][0]['message']['content'])
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/lib/_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742

# %%
New_dataset = pd.DataFrame({'Original_text': original_data, 'Augmented_Text': augmented_data1, 'Aspect': augmented_data_labels, 'Original_Explanation': original_explain, 'Augmented_Explanation': augmented_data2})

# %%
New_dataset
# Out:
#                                          Original_text  \
# 0    Once it happens there is no going back and you...
# 1    Now i am filled with guilt and stuck feeling l...
# 2    And i got home and the voices returned and kep...
# 3    Before her I survived since shit, sexual assau...
# 4    I feel like there are only three things that y...
# ..                                                 ...
# 115  Can't sleep at 3 in the morning, going through...
# 116  I have a medical condition that causes me to f...
# 117  I've had panic attacks before and tried to tal...
# 118  But I feel my anxiety creeps in again and mayb...
# 119  I've just been prescribed Citalopram 20mg - st...
#
#                                         Augmented_Text  Aspect  \
# 0    The spiritual and emotional aspect of life can...       4
# 1    My spiritual and emotional state is in turmoil...       4
# 2    After a long day, I found myself alone with my...       4
# 3    Despite the challenges I faced in terms of my ...       1
# 4    In terms of physical appearance, it seems like...       1
# ..                                                 ...     ...
# 115  Feeling exhausted and achy after a long day at...       1
# 116  I have been struggling with my physical appear...       1
# 117  When I mentioned to my friend that I was strug...       1
# 118  I've been feeling a bit out of shape lately an...       1
# 119  I have an upcoming appointment with my doctor ...       1
#
#                                   Original_Explanation  \
# 0                               empty void of darkness
# 1        filled with guilt and stuck feeling like crap
# 2                                        piece of shit
# 3                                      sexual assaults
# 4                              ugly, dumb, and useless
# ..                                                 ...
# 115         withdrawal symptoms, addicted to junk food
# 116                                  medical condition
# 117                                      panic attacks
# 118                                              pills
# 119  prescribed Citalopram 20mg - started treatment...
#
#                                  Augmented_Explanation
# 0    spiritual and emotional aspect of life can be ...
# 1    spiritual and emotional turmoil, heavy burden ...
# 2    negative self-talk and feeling worthless due t...
# 3                   persevered through difficult times
# 4                unacceptable physical characteristics
# ..                                                 ...
# 115  struggling to find motivation to exercise, con...
# 116  struggling with physical appearance and weight...
# 117                             struggling with weight
# 118  considering starting a new exercise routine to...
# 119  upcoming appointment to discuss potential trea...
#
# [120 rows x 5 columns]

# %%
New_dataset.to_csv("Stage2/Results/augmented_data_ChatGPT_model1_v3.csv", index=False)

# %%
data = pd.read_csv("Stage2/Results/augmented_data_ChatGPT_model1_v3.csv")
data

# %%
data['Aspect'].value_counts()

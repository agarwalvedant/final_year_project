# %% [markdown]
# # Viewing the data

# %%
import pandas as pd

# Load the dataset
file_path = 'dataset_wellnessdimensions.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset to understand its structure
data.head()
# Out:
#    Unnamed: 0                                               Text  Aspect  \
# 0           0  Once it happens there is no going back and you...       4
# 1           1  Now i am filled with guilt and stuck feeling l...       4
# 2           2  And i got home and the voices returned and kep...       4
# 3           3  Before her I survived since shit, sexual assau...       1
# 4           4  I feel like there are only three things that y...       1
#
#                                     Explanations
# 0                         empty void of darkness
# 1  filled with guilt and stuck feeling like crap
# 2                                  piece of shit
# 3                                sexual assaults
# 4                        ugly, dumb, and useless

# %%
print(data.describe())
# Out:
#         Unnamed: 0       Aspect
# count  3092.000000  3092.000000
# mean   1545.500000     2.530724
# std     892.727842     1.062901
# min       0.000000     1.000000
# 25%     772.750000     2.000000
# 50%    1545.500000     3.000000
# 75%    2318.250000     3.000000
# max    3091.000000     4.000000

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3092 entries, 0 to 3091
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    3092 non-null   int64
#  1   Text          3092 non-null   object
#  2   Aspect        3092 non-null   int64
#  3   Explanations  3092 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 96.8+ KB
# None

# %% [markdown]
# # Cleaning the data

# %%
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Error loading punkt: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1006)>
# [nltk_data] Error loading stopwords: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1006)>
# [nltk_data] Error loading wordnet: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1006)>
# False

# %%
# Initialize Lemmatizer
lemmatizer = WordNetLemmatizer()

# Define stop words and punctuation set
stop_words = set(stopwords.words('english'))
punctuation = set(string.punctuation)

# %%
# Function to clean and preprocess text
def preprocess_text(text):
    # Lowercase the text
    text = text.lower()
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stopwords and punctuation, and lemmatize the words
    cleaned_tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words and word not in punctuation]
    # Join tokens back into a string
    return ' '.join(cleaned_tokens)

# Apply the preprocessing to the 'Text' and 'Explanations' columns
data['Cleaned_Text'] = data['Text'].apply(preprocess_text)
data['Cleaned_Explanations'] = data['Explanations'].apply(preprocess_text)

# Drop unnecessary columns
cleaned_data = data[['Cleaned_Text', 'Cleaned_Explanations', 'Aspect']]

# Show the cleaned dataset
cleaned_data.head()
# Out:
#                                         Cleaned_Text  \
# 0  happens going back stuck empty void darkness f...
# 1               filled guilt stuck feeling like crap
# 2    got home voice returned kept telling piece shit
# 3            survived since shit sexual assault like
# 4  feel like three thing absolutely dumb ugly use...
#
#                    Cleaned_Explanations  Aspect
# 0                   empty void darkness       4
# 1  filled guilt stuck feeling like crap       4
# 2                            piece shit       4
# 3                        sexual assault       1
# 4                     ugly dumb useless       1

# %% [markdown]
# # Word cloud for clean explanation

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# Combine all the cleaned explanations into one large string
explanations_text = ' '.join(cleaned_data['Cleaned_Explanations'].astype(str))

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white', max_words=200).generate(explanations_text)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # No axis for a cleaner visualization
plt.title("Cleaned Explanations", fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Feature Engineering using TF-IDF for 'Cleaned_Text'
tfidf_vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')

# Apply TF-IDF to Cleaned_Text and Cleaned_Explanations
tfidf_text = tfidf_vectorizer.fit_transform(cleaned_data['Cleaned_Text'])
tfidf_explanations = tfidf_vectorizer.fit_transform(cleaned_data['Cleaned_Explanations'])

# Extract the feature names for word cloud creation
feature_names_text = tfidf_vectorizer.get_feature_names_out()
feature_names_explanations = tfidf_vectorizer.get_feature_names_out()

# Combine all feature names into a single string for word cloud visualization
tfidf_text_combined = ' '.join(feature_names_text)
tfidf_explanations_combined = ' '.join(feature_names_explanations)

# %% [markdown]
# # Word cloud after feature engineering

# %%
# Generate word clouds for both 'Cleaned_Text' and 'Cleaned_Explanations'
wordcloud_text = WordCloud(width=800, height=400, background_color='white').generate(tfidf_text_combined)
wordcloud_explanations = WordCloud(width=800, height=400, background_color='white').generate(tfidf_explanations_combined)

# Plot the word cloud for 'Cleaned_Text'
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_text, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Cleaned Text (After TF-IDF Feature Engineering)')
plt.show()

# Plot the word cloud for 'Cleaned_Explanations'
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_explanations, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Cleaned Explanations (After TF-IDF Feature Engineering)')
plt.show()

# %% [markdown]
# # Cleaning the training the dataset

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# %%
training_data = pd.read_csv('s1_training_dataset_chatgpt1.csv')
training_data.head()
# Out:
#                                                 Text  Aspect  \
# 0  I don't feel anything anymore and randomly bre...       1
# 1  Somebody I care very much for has been on esci...       1
# 2  Now, for the past week and a half, he's been f...       1
# 3  I've been depressed for more than a year now, ...       1
# 4  She's happier after she broke up with me, I fe...       1
#
#                         Explanations
# 0        randomly break down and cry
# 1          on escitalopram for years
# 2                             crying
# 3                     self-diagnosed
# 4  bipolar disorder, OCD and anxiety

# %%
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Initialize Lemmatizer
lemmatizer = WordNetLemmatizer()

# Define stop words and punctuation set
stop_words = set(stopwords.words('english'))
punctuation = set(string.punctuation)
# Function to clean and preprocess text
def preprocess_text(text):
    # Lowercase the text
    text = text.lower()
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stopwords and punctuation, and lemmatize the words
    cleaned_tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words and word not in punctuation]
    # Join tokens back into a string
    return ' '.join(cleaned_tokens)

# Apply the preprocessing to the 'Text' and 'Explanations' columns
training_data['Cleaned_Text'] = training_data['Text'].apply(preprocess_text)
training_data['Cleaned_Explanations'] = training_data['Explanations'].apply(preprocess_text)

# Drop unnecessary columns
cleaned_data_train = training_data[['Cleaned_Text', 'Cleaned_Explanations', 'Aspect']]

# Show the cleaned dataset
cleaned_data_train.head()
# Out:
# [nltk_data] Error loading punkt: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1006)>
# [nltk_data] Error loading stopwords: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1006)>
# [nltk_data] Error loading wordnet: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1006)>
#                                         Cleaned_Text  \
# 0       n't feel anything anymore randomly break cry
# 1  somebody care much escitalopram year due cripp...
# 2  past week half 's feeling emotional control pa...
# 3  've depressed year teenager self-diagnosed 'm ...
# 4  's happier broke feel like fault lost probably...
#
#            Cleaned_Explanations  Aspect
# 0            randomly break cry       1
# 1             escitalopram year       1
# 2                           cry       1
# 3                self-diagnosed       1
# 4  bipolar disorder ocd anxiety       1

# %%
# Feature Engineering using TF-IDF for 'Cleaned_Text'
tfidf_vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')

# Apply TF-IDF to Cleaned_Text and Cleaned_Explanations
tfidf_text = tfidf_vectorizer.fit_transform(cleaned_data_train['Cleaned_Text'])
tfidf_explanations = tfidf_vectorizer.fit_transform(cleaned_data_train['Cleaned_Explanations'])

# %% [markdown]
# # Attention based Autoencoder

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from tensorflow.keras import layers, models, backend as K
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')

# Apply TF-IDF
tfidf_text_wellness = tfidf_vectorizer.fit_transform(cleaned_data['Cleaned_Text'])
tfidf_explanations_wellness = tfidf_vectorizer.fit_transform(cleaned_data['Cleaned_Explanations'])

tfidf_text_training = tfidf_vectorizer.fit_transform(cleaned_data_train['Cleaned_Text'])
tfidf_explanations_training = tfidf_vectorizer.fit_transform(cleaned_data_train['Cleaned_Explanations'])

# Combine TF-IDF features
combined_tfidf_wellness = np.hstack([tfidf_text_wellness.toarray(), tfidf_explanations_wellness.toarray()])
combined_tfidf_training = np.hstack([tfidf_text_training.toarray(), tfidf_explanations_training.toarray()])
tfidf_vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')

# Apply TF-IDF
tfidf_text_wellness = tfidf_vectorizer.fit_transform(cleaned_data['Cleaned_Text'])
tfidf_explanations_wellness = tfidf_vectorizer.fit_transform(cleaned_data['Cleaned_Explanations'])

tfidf_text_training = tfidf_vectorizer.fit_transform(cleaned_data_train['Cleaned_Text'])
tfidf_explanations_training = tfidf_vectorizer.fit_transform(cleaned_data_train['Cleaned_Explanations'])

# Combine TF-IDF features
combined_tfidf_wellness = np.hstack([tfidf_text_wellness.toarray(), tfidf_explanations_wellness.toarray()])
combined_tfidf_training = np.hstack([tfidf_text_training.toarray(), tfidf_explanations_training.toarray()])

# %%
# Merge the two combined datasets
combined_data = np.vstack([combined_tfidf_wellness, combined_tfidf_training])

# Split the data into training and validation sets
X_train, X_val = train_test_split(combined_data, test_size=0.2, random_state=42)

# %%
# Step 2: Attention Layer Definition
def attention_3d_block(inputs):
    attention = layers.Dense(inputs.shape[-1], activation='tanh')(inputs)
    attention = layers.Dense(1, activation='softmax')(attention)
    attention = K.squeeze(attention, -1)
    attention = K.expand_dims(attention)
    weighted_inputs = inputs * attention
    return weighted_inputs

# %%
# Combine the TF-IDF features from both datasets
combined_tfidf_wellness = np.hstack([tfidf_text_wellness.toarray(), tfidf_explanations_wellness.toarray()])
combined_tfidf_training = np.hstack([tfidf_text_training.toarray(), tfidf_explanations_training.toarray()])

# %%
# Merge the two combined datasets for the autoencoder
combined_data = np.vstack([combined_tfidf_wellness, combined_tfidf_training])

# Split the data into training and validation sets
X_train, X_val = train_test_split(combined_data, test_size=0.2, random_state=42)

# %%
# Step 2: Attention Layer Definition
def attention_3d_block(inputs):
    # Input shape: (batch_size, timesteps, input_dim)
    attention = layers.Dense(inputs.shape[-1], activation='tanh')(inputs)
    attention = layers.Dense(1, activation='softmax')(attention)
    attention = K.squeeze(attention, -1)
    attention = K.expand_dims(attention)
    weighted_inputs = inputs * attention
    return weighted_inputs

# %%
input_dim = X_train.shape[1]

# %%
# Encoder
input_layer = layers.Input(shape=(input_dim,))
encoded = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001))(input_layer)
encoded = layers.Dropout(0.2)(encoded)
encoded = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001))(encoded)
encoded = layers.Dropout(0.2)(encoded)
encoded = layers.Reshape((256, 1))(encoded)

# Attention layer
attention = attention_3d_block(encoded)

# Flatten after attention
flattened = layers.Flatten()(attention)

# Decoder
decoded = layers.Dense(256, activation='relu')(flattened)
decoded = layers.Dropout(0.2)(decoded)
decoded = layers.Dense(512, activation='relu')(decoded)
decoded = layers.Dense(input_dim, activation='sigmoid')(decoded)

# Compile the model
autoencoder = models.Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='mse')

# %%
# Callbacks for early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# %%
# Step 4: Train the Model
history = autoencoder.fit(X_train, X_train,
                          epochs=100,
                          batch_size=16,
                          validation_data=(X_val, X_val),
                          callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/100
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5544e-04 - val_loss: 9.5544e-04 - lr: 3.9063e-06
# Epoch 2/100
# 374/374 [==============================] - 2s 4ms/step - loss: 9.5546e-04 - val_loss: 9.5545e-04 - lr: 3.9063e-06
# Epoch 3/100
# 374/374 [==============================] - 2s 4ms/step - loss: 9.5541e-04 - val_loss: 9.5544e-04 - lr: 3.9063e-06
# Epoch 4/100
# 374/374 [==============================] - 8s 21ms/step - loss: 9.5547e-04 - val_loss: 9.5544e-04 - lr: 3.9063e-06
# Epoch 5/100
# 374/374 [==============================] - 7s 20ms/step - loss: 9.5547e-04 - val_loss: 9.5545e-04 - lr: 3.9063e-06
# Epoch 6/100
# 374/374 [==============================] - 7s 19ms/step - loss: 9.5545e-04 - val_loss: 9.5544e-04 - lr: 3.9063e-06
# Epoch 7/100
# 374/374 [==============================] - 7s 19ms/step - loss: 9.5544e-04 - val_loss: 9.5544e-04 - lr: 1.9531e-06
# Epoch 8/100
# 374/374 [==============================] - 7s 19ms/step - loss: 9.5547e-04 - val_loss: 9.5544e-04 - lr: 1.9531e-06
# Epoch 9/100
# 374/374 [==============================] - 8s 21ms/step - loss: 9.5554e-04 - val_loss: 9.5544e-04 - lr: 1.9531e-06
# Epoch 10/100
# 374/374 [==============================] - 7s 19ms/step - loss: 9.5545e-04 - val_loss: 9.5544e-04 - lr: 1.9531e-06
# Epoch 11/100
# 374/374 [==============================] - 9s 24ms/step - loss: 9.5545e-04 - val_loss: 9.5544e-04 - lr: 1.9531e-06

# %%
# Step 5: Plotting the Loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Attention-Based Autoencoder Loss During Training')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
# Predict the reconstructed data using the trained autoencoder
reconstructed_data = autoencoder.predict(X_tfidf)

# Calculate the reconstruction error (mean squared error for each sample)
reconstruction_error = np.mean(np.square(X_tfidf - reconstructed_data), axis=1)

# Calculate the average reconstruction error for the training set
average_reconstruction_error_train = np.mean(reconstruction_error)

# Display the average reconstruction error
print(f"Average Reconstruction Error (Training Set): {average_reconstruction_error_train}")
# Out:
# 187/187 [==============================] - 0s 1ms/step
# Average Reconstruction Error (Training Set): 0.00095501138187698

# %%
# Step 6: Evaluate the Model with Reconstruction Error
reconstructed = autoencoder.predict(X_val)

# Calculate Mean Squared Error (MSE) for each sample
mse = np.mean(np.power(X_val - reconstructed, 2), axis=1)

# Calculate additional metrics (optional)
threshold = np.percentile(mse, 95)  # Set threshold for anomaly detection
print(f"95th percentile of reconstruction error: {threshold:.4f}")

# Plot the Reconstruction Error Distribution
plt.figure(figsize=(12, 6))
plt.hist(mse, bins=50, alpha=0.7, color='blue', edgecolor='black')
plt.axvline(threshold, color='red', linestyle='dashed', linewidth=1.5, label='Threshold (95th percentile)')
plt.title('Reconstruction Error Distribution')
plt.xlabel('Mean Squared Error (MSE)')
plt.ylabel('Number of Samples')
plt.legend()
plt.show()
# Out:
# 47/47 [==============================] - 0s 2ms/step
# 95th percentile of reconstruction error: 0.0010

# %%
# Plot reconstruction error for each sample
plt.figure(figsize=(12, 6))
plt.plot(reconstruction_error, label='Reconstruction Error', color='red', alpha=0.7)
plt.title('Reconstruction Error for Each Sample')
plt.xlabel('Sample Index')
plt.ylabel('Reconstruction Error (MSE)')
plt.axhline(y=np.mean(reconstruction_error), color='blue', linestyle='--', label='Mean Reconstruction Error')
plt.axhline(y=np.percentile(reconstruction_error, 95), color='orange', linestyle='--', label='95th Percentile Threshold')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Hyperparameter Optimization with Spider Monkey Algorithm (SMO)

# %%
# Spider Monkey Optimizer Class
class SpiderMonkeyOptimizer:
    def __init__(self, objective_function, num_spiders=10, max_iter=50):
        self.objective_function = objective_function
        self.num_spiders = num_spiders
        self.max_iter = max_iter

    def optimize(self):
        # Initialize random spider positions with constraints
        spiders = np.random.rand(self.num_spiders, 3)
        spiders[:, 0] = np.clip(spiders[:, 0] * 100, 1, None)  # units1 (1 to 100)
        spiders[:, 1] = np.clip(spiders[:, 1] * 100, 1, None)  # units2 (1 to 100)
        spiders[:, 2] = np.clip(spiders[:, 2] * 0.1, 0.0001, 0.01)  # learning_rate (0.0001 to 0.01)

        best_position = None
        best_score = float('inf')

        for iteration in range(self.max_iter):
            for i in range(self.num_spiders):
                score = self.objective_function(spiders[i])

                if score < best_score:
                    best_score = score
                    best_position = spiders[i]

            # Print the current best score and parameters at each iteration
            print(f"Iteration {iteration + 1}/{self.max_iter}, Best Score: {best_score}, Best Params: {best_position}")

            # Update spider positions (this can be adjusted based on your algorithm)
            spiders += np.random.randn(self.num_spiders, 3) * 0.1  # Random movement

        return best_position, best_score

# %%
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers.legacy import Adam

# Define the objective function for optimization
def objective_function(params):
    units1, units2, learning_rate = int(params[0]), int(params[1]), params[2]

    # Ensure that the number of units is positive
    if units1 <= 0 or units2 <= 0:
        return float('inf')  # Return a high score for invalid parameters

    # Build and compile the autoencoder model with current hyperparameters
    input_layer = layers.Input(shape=(input_dim,))
    encoded = layers.Dense(units1, activation='relu')(input_layer)
    encoded = layers.Dense(units2, activation='relu')(encoded)
    flattened = layers.Flatten()(encoded)

    # Decoder
    decoded = layers.Dense(units2, activation='relu')(flattened)
    decoded = layers.Dense(units1, activation='relu')(decoded)
    decoded = layers.Dense(input_dim, activation='sigmoid')(decoded)

    autoencoder = models.Model(input_layer, decoded)
    autoencoder.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')

    # Train the model
    history = autoencoder.fit(X_train, X_train, epochs=50, batch_size=32, validation_data=(X_val, X_val), verbose=0)

    # Return the validation loss for this set of parameters
    return history.history['val_loss'][-1]

# %%
# Initialize the optimizer
optimizer = SpiderMonkeyOptimizer(objective_function, num_spiders=10, max_iter=50)

# Run optimization
best_params, best_score = optimizer.optimize()

# Output the best parameters and score
print(f"Best Parameters: {best_params}, Best Score (Validation Loss): {best_score}")
# Out:
# Iteration 1/50, Best Score: 0.0009017160045914352, Best Params: [3.25140306e+01 2.62309232e+01 1.24934884e-03]
# Iteration 2/50, Best Score: 0.0009017160045914352, Best Params: [32.47370879 26.30344679 -0.14666794]
# Iteration 3/50, Best Score: 0.0009017160045914352, Best Params: [32.63788454 26.15159098  0.03776785]
# Iteration 4/50, Best Score: 0.0009017160045914352, Best Params: [32.67195392 26.37392872  0.15193724]
# Iteration 5/50, Best Score: 0.0009017160045914352, Best Params: [32.65661341 26.21567829  0.28953761]
# Iteration 6/50, Best Score: 0.0009017160045914352, Best Params: [32.54284573 26.10059883  0.35713945]
# Iteration 7/50, Best Score: 0.0009017160045914352, Best Params: [32.78811271 26.05860884  0.23441823]
# Iteration 8/50, Best Score: 0.0009017160045914352, Best Params: [32.79250496 25.93735163  0.18944737]
# Iteration 9/50, Best Score: 0.0009017160045914352, Best Params: [32.7350939  25.92855321  0.09046329]
# Iteration 10/50, Best Score: 0.0009017160045914352, Best Params: [32.64876325 25.67969632  0.0857478 ]
# Iteration 11/50, Best Score: 0.0009017160045914352, Best Params: [32.5324393  25.76365953  0.22515656]
# Iteration 12/50, Best Score: 0.0009017160045914352, Best Params: [32.49982509 25.85623963  0.20767793]
# Iteration 13/50, Best Score: 0.0009017160045914352, Best Params: [32.44328816 25.91067612  0.22274902]
# Iteration 14/50, Best Score: 0.0009017160045914352, Best Params: [32.27253133 26.01037843  0.20144547]
# Iteration 15/50, Best Score: 0.0009017160045914352, Best Params: [32.1917275  26.14810331  0.31555951]
# Iteration 16/50, Best Score: 0.0009017160045914352, Best Params: [32.17069681 26.18210019  0.3331392 ]
# Iteration 17/50, Best Score: 0.0009017160045914352, Best Params: [32.18100154 25.97667645  0.47227693]
# Iteration 18/50, Best Score: 0.0009017160045914352, Best Params: [32.08189094 26.01650916  0.49893276]
# Iteration 19/50, Best Score: 0.0009017160045914352, Best Params: [32.01626303 26.10408709  0.45159404]
# Iteration 20/50, Best Score: 0.0009017160045914352, Best Params: [31.86464249 26.07676861  0.49977424]
# Iteration 21/50, Best Score: 0.0009017160045914352, Best Params: [31.91711604 26.13521082  0.53347356]
# Iteration 22/50, Best Score: 0.0009017160045914352, Best Params: [31.89057562 26.29392875  0.40370975]
# Iteration 23/50, Best Score: 0.0009017160045914352, Best Params: [31.98971257 26.33940117  0.24985073]
# Iteration 24/50, Best Score: 0.0009017160045914352, Best Params: [32.07956839 26.3069949   0.22045956]
# Iteration 25/50, Best Score: 0.0009017160045914352, Best Params: [31.955999   26.23980823  0.17186125]
# Iteration 26/50, Best Score: 0.0009017160045914352, Best Params: [31.78873591 26.20383327  0.17844342]
# Iteration 27/50, Best Score: 0.0009017160045914352, Best Params: [31.45935077 26.1646717   0.08293342]
# Iteration 28/50, Best Score: 0.0009017160045914352, Best Params: [31.43414891 26.19637965  0.09858789]
# Iteration 29/50, Best Score: 0.0009017160045914352, Best Params: [31.34918119 26.29539424  0.05819801]
# Iteration 30/50, Best Score: 0.0009017160045914352, Best Params: [31.14082971 26.31612814 -0.10236079]
# Iteration 31/50, Best Score: 0.0009017160045914352, Best Params: [30.85106112 26.27821812  0.0565893 ]
# Iteration 32/50, Best Score: 0.0009017160045914352, Best Params: [30.67163621 26.18128679  0.08435772]
# Iteration 33/50, Best Score: 0.0009017160045914352, Best Params: [ 3.07979556e+01  2.61356438e+01 -2.74150196e-02]
# Iteration 34/50, Best Score: 0.0009017160045914352, Best Params: [30.84556003 26.04189188 -0.0929252 ]
# Iteration 35/50, Best Score: 0.0009017160045914352, Best Params: [30.84092995 25.9562211  -0.08982405]
# Iteration 36/50, Best Score: 0.0009017160045914352, Best Params: [30.84027769 25.88811432  0.03109962]
# Iteration 37/50, Best Score: 0.0009017160045914352, Best Params: [ 3.08532551e+01  2.58884875e+01 -2.83799827e-03]
# Iteration 38/50, Best Score: 0.0009017160045914352, Best Params: [30.81734047 25.81156202  0.1747346 ]
# Iteration 39/50, Best Score: 0.0009017160045914352, Best Params: [30.94247914 25.84044338  0.20147715]
# Iteration 40/50, Best Score: 0.0009017160045914352, Best Params: [30.9947999  25.92088919  0.23469925]
# Iteration 41/50, Best Score: 0.0009017160045914352, Best Params: [30.9288368  25.90612917  0.35591825]
# Iteration 42/50, Best Score: 0.0009017160045914352, Best Params: [30.7192641  25.92489937  0.11732513]
# Iteration 43/50, Best Score: 0.0009017160045914352, Best Params: [30.71929416 25.95441515  0.08676738]
# Iteration 44/50, Best Score: 0.0009017160045914352, Best Params: [30.44668961 26.05226376  0.04407353]
# Iteration 45/50, Best Score: 0.0009017160045914352, Best Params: [3.04907806e+01 2.60899762e+01 1.42869290e-02]
# Iteration 46/50, Best Score: 0.0009017160045914352, Best Params: [30.3916538  26.07859671  0.07880479]
# Iteration 47/50, Best Score: 0.0009017160045914352, Best Params: [30.22927783 26.08981016  0.03358932]
# Iteration 48/50, Best Score: 0.0009017160045914352, Best Params: [ 3.01855705e+01  2.60834742e+01 -1.47487562e-03]
# Iteration 49/50, Best Score: 0.0009017160045914352, Best Params: [30.25504033 26.18423765 -0.05867273]
# Iteration 50/50, Best Score: 0.0009017160045914352, Best Params: [3.03700273e+01 2.62900028e+01 1.00963416e-02]
# Best Parameters: [30.36875221 26.23017318  0.1236038 ], Best Score (Validation Loss): 0.0009017160045914352

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
import matplotlib.pyplot as plt

# Build a more complex autoencoder model
final_autoencoder = models.Sequential([
    layers.Input(shape=(X_tfidf.shape[1],)),
    layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01)),  # Increased neurons
    layers.Dropout(0.2),  # Dropout layer
    layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.2),  # Dropout layer
    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)),  # Bottleneck layer
    layers.Dense(256, activation='relu'),
    layers.Dense(512, activation='relu'),
    layers.Dense(X_tfidf.shape[1], activation='sigmoid')  # Output layer
])

# Compile the model with a potentially adjusted learning rate
final_optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=best_learning_rate)
final_autoencoder.compile(optimizer=final_optimizer, loss='mean_squared_error')

# Train the final autoencoder with the best hyperparameters
history = final_autoencoder.fit(X_tfidf, X_tfidf,
                                 epochs=50,  # Increase epochs
                                 batch_size=best_batch_size,
                                 validation_split=0.2,
                                 verbose=1)

# Plot the training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Final Autoencoder Loss During Training')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# Predict the reconstructed data using the trained autoencoder
reconstructed_data = final_autoencoder.predict(X_tfidf)

# Calculate the reconstruction error (mean squared error for each sample)
reconstruction_error = np.mean(np.square(X_tfidf - reconstructed_data), axis=1)

# Calculate the average reconstruction error for the training set
average_reconstruction_error_train = np.mean(reconstruction_error)

# Display the average reconstruction error
print(f"Average Reconstruction Error (Training Set): {average_reconstruction_error_train}")

# Plot reconstruction error for each sample
plt.figure(figsize=(10, 6))
plt.plot(reconstruction_error, label='Reconstruction Error', color='red')
plt.title('Reconstruction Error for Each Sample')
plt.xlabel('Sample Index')
plt.ylabel('Reconstruction Error')
plt.grid(True)
plt.show()
# Out:
# Epoch 1/50
# 184/184 [==============================] - 1s 4ms/step - loss: 2.4877 - val_loss: 9.6720e-04
# Epoch 2/50
# 184/184 [==============================] - 1s 4ms/step - loss: 9.6402e-04 - val_loss: 9.6695e-04
# Epoch 3/50
# 184/184 [==============================] - 1s 4ms/step - loss: 9.6401e-04 - val_loss: 9.6695e-04
# Epoch 4/50
# 184/184 [==============================] - 1s 4ms/step - loss: 9.6401e-04 - val_loss: 9.6695e-04
# Epoch 5/50
# 184/184 [==============================] - 1s 4ms/step - loss: 9.6591e-04 - val_loss: 9.6707e-04
# Epoch 6/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 7/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 8/50
# 184/184 [==============================] - 1s 5ms/step - loss: 0.2077 - val_loss: 0.2639
# Epoch 9/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.2449 - val_loss: 0.2410
# Epoch 10/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.2172 - val_loss: 0.2188
# Epoch 11/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.2221 - val_loss: 0.2928
# Epoch 12/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0635 - val_loss: 0.0104
# Epoch 13/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1087 - val_loss: 0.1678
# Epoch 14/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1435 - val_loss: 0.1333
# Epoch 15/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1558 - val_loss: 0.1583
# Epoch 16/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1537 - val_loss: 0.1563
# Epoch 17/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.2132 - val_loss: 0.1320
# Epoch 18/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1121 - val_loss: 0.0907
# Epoch 19/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1054 - val_loss: 0.1383
# Epoch 20/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1328 - val_loss: 0.1483
# Epoch 21/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.2037 - val_loss: 0.2215
# Epoch 22/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1314 - val_loss: 0.0796
# Epoch 23/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0963 - val_loss: 0.1189
# Epoch 24/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1614 - val_loss: 0.1748
# Epoch 25/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1809 - val_loss: 0.1568
# Epoch 26/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0852 - val_loss: 0.1001
# Epoch 27/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1430 - val_loss: 0.1633
# Epoch 28/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1592 - val_loss: 0.1601
# Epoch 29/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1166 - val_loss: 0.0925
# Epoch 30/50
# 184/184 [==============================] - 1s 5ms/step - loss: 0.1357 - val_loss: 0.1541
# Epoch 31/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1477 - val_loss: 0.1459
# Epoch 32/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1241 - val_loss: 0.1084
# Epoch 33/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1356 - val_loss: 0.1403
# Epoch 34/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1400 - val_loss: 0.1417
# Epoch 35/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1279 - val_loss: 0.1279
# Epoch 36/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1353 - val_loss: 0.1375
# Epoch 37/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1359 - val_loss: 0.1402
# Epoch 38/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1312 - val_loss: 0.1322
# Epoch 39/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1325 - val_loss: 0.1297
# Epoch 40/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1347 - val_loss: 0.1342
# Epoch 41/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1331 - val_loss: 0.1324
# Epoch 42/50
# 184/184 [==============================] - 1s 5ms/step - loss: 0.1299 - val_loss: 0.1318
# Epoch 43/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1358 - val_loss: 0.1375
# Epoch 44/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1325 - val_loss: 0.1288
# Epoch 45/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1297 - val_loss: 0.1342
# Epoch 46/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1362 - val_loss: 0.1341
# Epoch 47/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1298 - val_loss: 0.1273
# Epoch 48/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1327 - val_loss: 0.1376
# Epoch 49/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1349 - val_loss: 0.1308
# Epoch 50/50
# 184/184 [==============================] - 1s 4ms/step - loss: 0.1288 - val_loss: 0.1302
# 187/187 [==============================] - 0s 1ms/step
# Average Reconstruction Error (Training Set): 0.0009645965852025446

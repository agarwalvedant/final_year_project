# %% [markdown]
# # Viewing the data

# %%
import pandas as pd

# Load the dataset
file_path = 'dataset_wellnessdimensions.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset to understand its structure
data.head()
# Out:
#    Unnamed: 0                                               Text  Aspect  \
# 0           0  Once it happens there is no going back and you...       4
# 1           1  Now i am filled with guilt and stuck feeling l...       4
# 2           2  And i got home and the voices returned and kep...       4
# 3           3  Before her I survived since shit, sexual assau...       1
# 4           4  I feel like there are only three things that y...       1
#
#                                     Explanations
# 0                         empty void of darkness
# 1  filled with guilt and stuck feeling like crap
# 2                                  piece of shit
# 3                                sexual assaults
# 4                        ugly, dumb, and useless

# %%
print(data.describe())
# Out:
#         Unnamed: 0       Aspect
# count  3092.000000  3092.000000
# mean   1545.500000     2.530724
# std     892.727842     1.062901
# min       0.000000     1.000000
# 25%     772.750000     2.000000
# 50%    1545.500000     3.000000
# 75%    2318.250000     3.000000
# max    3091.000000     4.000000

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3092 entries, 0 to 3091
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    3092 non-null   int64
#  1   Text          3092 non-null   object
#  2   Aspect        3092 non-null   int64
#  3   Explanations  3092 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 96.8+ KB
# None

# %% [markdown]
# # Cleaning the data

# %%
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/vedantagarwal/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/vedantagarwal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/vedantagarwal/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Initialize Lemmatizer
lemmatizer = WordNetLemmatizer()

# Define stop words and punctuation set
stop_words = set(stopwords.words('english'))
punctuation = set(string.punctuation)

# %%
# Function to clean and preprocess text
def preprocess_text(text):
    # Lowercase the text
    text = text.lower()
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stopwords and punctuation, and lemmatize the words
    cleaned_tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words and word not in punctuation]
    # Join tokens back into a string
    return ' '.join(cleaned_tokens)

# Apply the preprocessing to the 'Text' and 'Explanations' columns
data['Cleaned_Text'] = data['Text'].apply(preprocess_text)
data['Cleaned_Explanations'] = data['Explanations'].apply(preprocess_text)

# Drop unnecessary columns
cleaned_data = data[['Cleaned_Text', 'Cleaned_Explanations', 'Aspect']]

# Show the cleaned dataset
cleaned_data.head()
# Out:
#                                         Cleaned_Text  \
# 0  happens going back stuck empty void darkness f...
# 1               filled guilt stuck feeling like crap
# 2    got home voice returned kept telling piece shit
# 3            survived since shit sexual assault like
# 4  feel like three thing absolutely dumb ugly use...
#
#                    Cleaned_Explanations  Aspect
# 0                   empty void darkness       4
# 1  filled guilt stuck feeling like crap       4
# 2                            piece shit       4
# 3                        sexual assault       1
# 4                     ugly dumb useless       1

# %% [markdown]
# # Word cloud for clean explanation

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# Combine all the cleaned explanations into one large string
explanations_text = ' '.join(cleaned_data['Cleaned_Explanations'].astype(str))

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white', max_words=200).generate(explanations_text)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # No axis for a cleaner visualization
plt.title("Cleaned Explanations", fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Feature Engineering using TF-IDF for 'Cleaned_Text'
tfidf_vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')

# Apply TF-IDF to Cleaned_Text and Cleaned_Explanations
tfidf_text = tfidf_vectorizer.fit_transform(cleaned_data['Cleaned_Text'])
tfidf_explanations = tfidf_vectorizer.fit_transform(cleaned_data['Cleaned_Explanations'])

# Extract the feature names for word cloud creation
feature_names_text = tfidf_vectorizer.get_feature_names_out()
feature_names_explanations = tfidf_vectorizer.get_feature_names_out()

# Combine all feature names into a single string for word cloud visualization
tfidf_text_combined = ' '.join(feature_names_text)
tfidf_explanations_combined = ' '.join(feature_names_explanations)

# %% [markdown]
# # Word cloud after feature engineering

# %%
# Generate word clouds for both 'Cleaned_Text' and 'Cleaned_Explanations'
wordcloud_text = WordCloud(width=800, height=400, background_color='white').generate(tfidf_text_combined)
wordcloud_explanations = WordCloud(width=800, height=400, background_color='white').generate(tfidf_explanations_combined)

# Plot the word cloud for 'Cleaned_Text'
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_text, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Cleaned Text (After TF-IDF Feature Engineering)')
plt.show()

# Plot the word cloud for 'Cleaned_Explanations'
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_explanations, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Cleaned Explanations (After TF-IDF Feature Engineering)')
plt.show()

# %% [markdown]
# # Cleaning the training the dataset

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# %%
training_data = pd.read_csv('s1_training_dataset_chatgpt1.csv')
training_data.head()
# Out:
#                                                 Text  Aspect  \
# 0  I don't feel anything anymore and randomly bre...       1
# 1  Somebody I care very much for has been on esci...       1
# 2  Now, for the past week and a half, he's been f...       1
# 3  I've been depressed for more than a year now, ...       1
# 4  She's happier after she broke up with me, I fe...       1
#
#                         Explanations
# 0        randomly break down and cry
# 1          on escitalopram for years
# 2                             crying
# 3                     self-diagnosed
# 4  bipolar disorder, OCD and anxiety

# %%
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Initialize Lemmatizer
lemmatizer = WordNetLemmatizer()

# Define stop words and punctuation set
stop_words = set(stopwords.words('english'))
punctuation = set(string.punctuation)
# Function to clean and preprocess text
def preprocess_text(text):
    # Lowercase the text
    text = text.lower()
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stopwords and punctuation, and lemmatize the words
    cleaned_tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words and word not in punctuation]
    # Join tokens back into a string
    return ' '.join(cleaned_tokens)

# Apply the preprocessing to the 'Text' and 'Explanations' columns
training_data['Cleaned_Text'] = training_data['Text'].apply(preprocess_text)
training_data['Cleaned_Explanations'] = training_data['Explanations'].apply(preprocess_text)

# Drop unnecessary columns
cleaned_data_train = training_data[['Cleaned_Text', 'Cleaned_Explanations', 'Aspect']]

# Show the cleaned dataset
cleaned_data_train.head()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/vedantagarwal/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/vedantagarwal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/vedantagarwal/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                         Cleaned_Text  \
# 0       n't feel anything anymore randomly break cry
# 1  somebody care much escitalopram year due cripp...
# 2  past week half 's feeling emotional control pa...
# 3  've depressed year teenager self-diagnosed 'm ...
# 4  's happier broke feel like fault lost probably...
#
#            Cleaned_Explanations  Aspect
# 0            randomly break cry       1
# 1             escitalopram year       1
# 2                           cry       1
# 3                self-diagnosed       1
# 4  bipolar disorder ocd anxiety       1

# %%
# Feature Engineering using TF-IDF for 'Cleaned_Text'
tfidf_vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')

# Apply TF-IDF to Cleaned_Text and Cleaned_Explanations
tfidf_text = tfidf_vectorizer.fit_transform(cleaned_data_train['Cleaned_Text'])
tfidf_explanations = tfidf_vectorizer.fit_transform(cleaned_data_train['Cleaned_Explanations'])

# %% [markdown]
# # Attention based Autoencoder

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from tensorflow.keras import layers, models, backend as K
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')

# Apply TF-IDF
tfidf_text_wellness = tfidf_vectorizer.fit_transform(cleaned_data['Cleaned_Text'])
tfidf_explanations_wellness = tfidf_vectorizer.fit_transform(cleaned_data['Cleaned_Explanations'])

tfidf_text_training = tfidf_vectorizer.fit_transform(cleaned_data_train['Cleaned_Text'])
tfidf_explanations_training = tfidf_vectorizer.fit_transform(cleaned_data_train['Cleaned_Explanations'])

# Combine TF-IDF features
combined_tfidf_wellness = np.hstack([tfidf_text_wellness.toarray(), tfidf_explanations_wellness.toarray()])
combined_tfidf_training = np.hstack([tfidf_text_training.toarray(), tfidf_explanations_training.toarray()])
tfidf_vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')

# Apply TF-IDF
tfidf_text_wellness = tfidf_vectorizer.fit_transform(cleaned_data['Cleaned_Text'])
tfidf_explanations_wellness = tfidf_vectorizer.fit_transform(cleaned_data['Cleaned_Explanations'])

tfidf_text_training = tfidf_vectorizer.fit_transform(cleaned_data_train['Cleaned_Text'])
tfidf_explanations_training = tfidf_vectorizer.fit_transform(cleaned_data_train['Cleaned_Explanations'])

# Combine TF-IDF features
combined_tfidf_wellness = np.hstack([tfidf_text_wellness.toarray(), tfidf_explanations_wellness.toarray()])
combined_tfidf_training = np.hstack([tfidf_text_training.toarray(), tfidf_explanations_training.toarray()])

# %%
# Merge the two combined datasets
combined_data = np.vstack([combined_tfidf_wellness, combined_tfidf_training])

# Split the data into training and validation sets
X_train, X_val = train_test_split(combined_data, test_size=0.2, random_state=42)

# %%
# Step 2: Attention Layer Definition
def attention_3d_block(inputs):
    attention = layers.Dense(inputs.shape[-1], activation='tanh')(inputs)
    attention = layers.Dense(1, activation='softmax')(attention)
    attention = K.squeeze(attention, -1)
    attention = K.expand_dims(attention)
    weighted_inputs = inputs * attention
    return weighted_inputs

# %%
# Combine the TF-IDF features from both datasets
combined_tfidf_wellness = np.hstack([tfidf_text_wellness.toarray(), tfidf_explanations_wellness.toarray()])
combined_tfidf_training = np.hstack([tfidf_text_training.toarray(), tfidf_explanations_training.toarray()])

# %%
# Merge the two combined datasets for the autoencoder
combined_data = np.vstack([combined_tfidf_wellness, combined_tfidf_training])

# Split the data into training and validation sets
X_train, X_val = train_test_split(combined_data, test_size=0.2, random_state=42)

# %%
# Step 2: Attention Layer Definition
def attention_3d_block(inputs):
    # Input shape: (batch_size, timesteps, input_dim)
    attention = layers.Dense(inputs.shape[-1], activation='tanh')(inputs)
    attention = layers.Dense(1, activation='softmax')(attention)
    attention = K.squeeze(attention, -1)
    attention = K.expand_dims(attention)
    weighted_inputs = inputs * attention
    return weighted_inputs

# %%
input_dim = X_train.shape[1]

# %%
# Encoder
input_layer = layers.Input(shape=(input_dim,))
encoded = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001))(input_layer)
encoded = layers.Dropout(0.2)(encoded)
encoded = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001))(encoded)
encoded = layers.Dropout(0.2)(encoded)
encoded = layers.Reshape((256, 1))(encoded)

# Attention layer
attention = attention_3d_block(encoded)

# Flatten after attention
flattened = layers.Flatten()(attention)

# Decoder
decoded = layers.Dense(256, activation='relu')(flattened)
decoded = layers.Dropout(0.2)(decoded)
decoded = layers.Dense(512, activation='relu')(decoded)
decoded = layers.Dense(input_dim, activation='sigmoid')(decoded)

# Compile the model
autoencoder = models.Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='mse')

# %%
# Callbacks for early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# %%
# Step 4: Train the Model
history = autoencoder.fit(X_train, X_train,
                          epochs=50,
                          batch_size=16,
                          validation_data=(X_val, X_val),
                          )
# Out:
# Epoch 1/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5552e-04 - val_loss: 9.5544e-04
# Epoch 2/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5544e-04 - val_loss: 9.5544e-04
# Epoch 3/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5545e-04 - val_loss: 9.5544e-04
# Epoch 4/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5547e-04 - val_loss: 9.5545e-04
# Epoch 5/50
# 374/374 [==============================] - 2s 4ms/step - loss: 9.5546e-04 - val_loss: 9.5544e-04
# Epoch 6/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5547e-04 - val_loss: 9.5545e-04
# Epoch 7/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5541e-04 - val_loss: 9.5544e-04
# Epoch 8/50
# 374/374 [==============================] - 2s 4ms/step - loss: 9.5541e-04 - val_loss: 9.5544e-04
# Epoch 9/50
# 374/374 [==============================] - 2s 4ms/step - loss: 9.5545e-04 - val_loss: 9.5544e-04
# Epoch 10/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5549e-04 - val_loss: 9.5543e-04
# Epoch 11/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5539e-04 - val_loss: 9.5544e-04
# Epoch 12/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5544e-04 - val_loss: 9.5543e-04
# Epoch 13/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5546e-04 - val_loss: 9.5544e-04
# Epoch 14/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5543e-04 - val_loss: 9.5544e-04
# Epoch 15/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5543e-04 - val_loss: 9.5543e-04
# Epoch 16/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5542e-04 - val_loss: 9.5543e-04
# Epoch 17/50
# 374/374 [==============================] - 2s 4ms/step - loss: 9.5546e-04 - val_loss: 9.5544e-04
# Epoch 18/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5542e-04 - val_loss: 9.5543e-04
# Epoch 19/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5546e-04 - val_loss: 9.5544e-04
# Epoch 20/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5544e-04 - val_loss: 9.5544e-04
# Epoch 21/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5544e-04 - val_loss: 9.5544e-04
# Epoch 22/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5545e-04 - val_loss: 9.5544e-04
# Epoch 23/50
# 374/374 [==============================] - 2s 4ms/step - loss: 9.5546e-04 - val_loss: 9.5544e-04
# Epoch 24/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5545e-04 - val_loss: 9.5543e-04
# Epoch 25/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5541e-04 - val_loss: 9.5544e-04
# Epoch 26/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5547e-04 - val_loss: 9.5544e-04
# Epoch 27/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5546e-04 - val_loss: 9.5545e-04
# Epoch 28/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5546e-04 - val_loss: 9.5543e-04
# Epoch 29/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5545e-04 - val_loss: 9.5543e-04
# Epoch 30/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5546e-04 - val_loss: 9.5544e-04
# Epoch 31/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5543e-04 - val_loss: 9.5544e-04
# Epoch 32/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5548e-04 - val_loss: 9.5544e-04
# Epoch 33/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5546e-04 - val_loss: 9.5544e-04
# Epoch 34/50
# 374/374 [==============================] - 2s 4ms/step - loss: 9.5546e-04 - val_loss: 9.5544e-04
# Epoch 35/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5547e-04 - val_loss: 9.5544e-04
# Epoch 36/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5543e-04 - val_loss: 9.5544e-04
# Epoch 37/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5547e-04 - val_loss: 9.5544e-04
# Epoch 38/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5541e-04 - val_loss: 9.5544e-04
# Epoch 39/50
# 374/374 [==============================] - 2s 6ms/step - loss: 9.5545e-04 - val_loss: 9.5543e-04
# Epoch 40/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5546e-04 - val_loss: 9.5543e-04
# Epoch 41/50
# 374/374 [==============================] - 2s 6ms/step - loss: 9.5543e-04 - val_loss: 9.5544e-04
# Epoch 42/50
# 374/374 [==============================] - 2s 6ms/step - loss: 9.5543e-04 - val_loss: 9.5544e-04
# Epoch 43/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5545e-04 - val_loss: 9.5544e-04
# Epoch 44/50
# 374/374 [==============================] - 2s 7ms/step - loss: 9.5545e-04 - val_loss: 9.5545e-04
# Epoch 45/50
# 374/374 [==============================] - 2s 6ms/step - loss: 9.5545e-04 - val_loss: 9.5544e-04
# Epoch 46/50
# 374/374 [==============================] - 2s 5ms/step - loss: 9.5547e-04 - val_loss: 9.5546e-04
# Epoch 47/50
# 374/374 [==============================] - 2s 6ms/step - loss: 9.5544e-04 - val_loss: 9.5545e-04
# Epoch 48/50
# 374/374 [==============================] - 2s 6ms/step - loss: 9.5542e-04 - val_loss: 9.5544e-04
# Epoch 49/50
# 374/374 [==============================] - 2s 6ms/step - loss: 9.5541e-04 - val_loss: 9.5543e-04
# Epoch 50/50
# 374/374 [==============================] - 2s 6ms/step - loss: 9.5546e-04 - val_loss: 9.5544e-04

# %%
# Step 5: Plotting the Loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Attention-Based Autoencoder Loss During Training')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
X_tfidf = X_train
# Predict the reconstructed data using the trained autoencoder
reconstructed_data = autoencoder.predict(X_tfidf)

# Calculate the reconstruction error (mean squared error for each sample)
reconstruction_error = np.mean(np.square(X_tfidf - reconstructed_data), axis=1)

# Calculate the average reconstruction error for the training set
average_reconstruction_error_train = np.mean(reconstruction_error)

# Display the average reconstruction error
print(f"Average Reconstruction Error (Training Set): {average_reconstruction_error_train}")
# Out:
# 187/187 [==============================] - 0s 2ms/step
# Average Reconstruction Error (Training Set): 0.0009550222295880156

# %%
# Step 6: Evaluate the Model with Reconstruction Error
reconstructed = autoencoder.predict(X_val)

# Calculate Mean Squared Error (MSE) for each sample
mse = np.mean(np.power(X_val - reconstructed, 2), axis=1)

# Calculate additional metrics (optional)
threshold = np.percentile(mse, 95)  # Set threshold for anomaly detection
print(f"95th percentile of reconstruction error: {threshold:.4f}")

# Plot the Reconstruction Error Distribution
plt.figure(figsize=(12, 6))
plt.hist(mse, bins=50, alpha=0.7, color='blue', edgecolor='black')
plt.axvline(threshold, color='red', linestyle='dashed', linewidth=1.5, label='Threshold (95th percentile)')
plt.title('Reconstruction Error Distribution')
plt.xlabel('Mean Squared Error (MSE)')
plt.ylabel('Number of Samples')
plt.legend()
plt.show()
# Out:
# 47/47 [==============================] - 0s 2ms/step
# 95th percentile of reconstruction error: 0.0010

# %%
# Plot reconstruction error for each sample
plt.figure(figsize=(12, 6))
plt.plot(reconstruction_error, label='Reconstruction Error', color='red', alpha=0.7)
plt.title('Reconstruction Error for Each Sample')
plt.xlabel('Sample Index')
plt.ylabel('Reconstruction Error (MSE)')
plt.axhline(y=np.mean(reconstruction_error), color='blue', linestyle='--', label='Mean Reconstruction Error')
plt.axhline(y=np.percentile(reconstruction_error, 95), color='orange', linestyle='--', label='95th Percentile Threshold')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Hyperparameter Optimization with Spider Monkey Algorithm (SMO)

# %%
class SpiderMonkeyOptimizer:
    def __init__(self, objective_function, num_spiders=10, max_iter=50, inertia_weight=0.7, cognitive=1.5, social=1.5):
        self.objective_function = objective_function
        self.num_spiders = num_spiders
        self.max_iter = max_iter
        self.inertia_weight = inertia_weight
        self.cognitive = cognitive
        self.social = social

    def optimize(self):
        # Initialize random spider positions and velocities
        spiders = np.random.rand(self.num_spiders, 3)
        spiders[:, 0] = np.clip(spiders[:, 0] * 100, 1, 100)  # units1 (1 to 100)
        spiders[:, 1] = np.clip(spiders[:, 1] * 100, 1, 100)  # units2 (1 to 100)
        spiders[:, 2] = np.clip(spiders[:, 2] * 0.01, 0.0001, 0.01)  # learning_rate (0.0001 to 0.01)
        velocities = np.random.randn(self.num_spiders, 3) * 0.01  # Small initial velocities

        best_position = spiders[0].copy()
        best_score = float('inf')
        personal_best_positions = spiders.copy()
        personal_best_scores = np.full(self.num_spiders, np.inf)

        for iteration in range(self.max_iter):
            for i in range(self.num_spiders):
                score = self.objective_function(spiders[i])
                if score < personal_best_scores[i]:
                    personal_best_scores[i] = score
                    personal_best_positions[i] = spiders[i].copy()
                if score < best_score:
                    best_score = score
                    best_position = spiders[i].copy()

            # Print the current best score and parameters at each iteration
            print(f"Iteration {iteration + 1}/{self.max_iter}, Best Score: {best_score}, Best Params: {best_position}")

            # Update spider velocities and positions using PSO-like update rules
            velocities = (self.inertia_weight * velocities +
                          self.cognitive * np.random.rand(self.num_spiders, 3) * (personal_best_positions - spiders) +
                          self.social * np.random.rand(self.num_spiders, 3) * (best_position - spiders))
            spiders = np.clip(spiders + velocities, [1, 1, 0.0001], [100, 100, 0.01])

        return best_position, best_score

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers.legacy import Adam 

def objective_function(params):
    units1, units2, learning_rate = int(params[0]), int(params[1]), params[2]

    # Build and compile the autoencoder model
    input_layer = layers.Input(shape=(X_tfidf.shape[1],))
    encoded = layers.Dense(units1, activation='relu', kernel_regularizer=regularizers.l2(0.01))(input_layer)
    encoded = layers.Dropout(0.3)(encoded)  # Add dropout for regularization
    encoded = layers.Dense(units2, activation='relu', kernel_regularizer=regularizers.l2(0.01))(encoded)
    encoded = layers.Dropout(0.3)(encoded)

    decoded = layers.Dense(units2, activation='relu')(encoded)
    decoded = layers.Dense(units1, activation='relu')(decoded)
    decoded = layers.Dense(X_tfidf.shape[1], activation='sigmoid')(decoded)  # Output layer

    autoencoder = models.Model(input_layer, decoded)
    autoencoder.compile(optimizer=Adam(learning_rate=learning_rate), loss='mean_squared_error')

    # Implement early stopping and learning rate reduction on plateau
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)

    # Train the model
    history = autoencoder.fit(X_train, X_train, epochs=10, batch_size=32, 
                              validation_data=(X_val, X_val), verbose=0,
                              callbacks=[early_stopping, reduce_lr])

    # Return the validation loss for the best epoch
    return min(history.history['val_loss'])

# %%
# Initialize the optimizer
optimizer = SpiderMonkeyOptimizer(objective_function, num_spiders=10, max_iter=10)

# Run optimization
best_params, best_score = optimizer.optimize()

# Output the best parameters and score
print(f"Best Parameters: {best_params}, Best Score (Validation Loss): {best_score}")
# Out:
# Iteration 1/10, Best Score: 0.0009562489576637745, Best Params: [7.69702105e+01 4.69279687e+00 4.79883735e-03]
# Iteration 2/10, Best Score: 0.0009560385369695723, Best Params: [7.69761493e+01 4.69360156e+00 5.19228053e-03]
# Iteration 3/10, Best Score: 0.0009558597230352461, Best Params: [8.32810474e+01 3.76573709e+00 8.50596564e-03]
# Iteration 4/10, Best Score: 0.0009555713040754199, Best Params: [8.55161323e+01 4.11812160e+00 6.15579665e-03]
# Iteration 5/10, Best Score: 0.0009555713040754199, Best Params: [8.55161323e+01 4.11812160e+00 6.15579665e-03]
# Iteration 6/10, Best Score: 0.0009554412099532783, Best Params: [8.76197389e+01 4.25831654e+00 9.18155900e-03]
# Iteration 7/10, Best Score: 0.0009554412099532783, Best Params: [8.76197389e+01 4.25831654e+00 9.18155900e-03]
# Iteration 8/10, Best Score: 0.0009554412099532783, Best Params: [8.76197389e+01 4.25831654e+00 9.18155900e-03]
# Iteration 9/10, Best Score: 0.0009554396965540946, Best Params: [8.64957791e+01 4.08639565e+00 8.66455061e-03]
# Iteration 10/10, Best Score: 0.0009554396965540946, Best Params: [8.64957791e+01 4.08639565e+00 8.66455061e-03]
# Best Parameters: [8.64957791e+01 4.08639565e+00 8.66455061e-03], Best Score (Validation Loss): 0.0009554396965540946

# %%
# Build and compile the final autoencoder model with best parameters
final_autoencoder = models.Sequential([
    layers.Input(shape=(X_tfidf.shape[1],)),
    layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.3),  # Increased dropout to prevent overfitting
    layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.3),
    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)),  # Bottleneck layer
    layers.Dense(256, activation='relu'),
    layers.Dense(512, activation='relu'),
    layers.Dense(X_tfidf.shape[1], activation='sigmoid')  # Output layer
])

# Compile the model with the best learning rate found
final_optimizer = Adam(learning_rate=best_params[2])
final_autoencoder.compile(optimizer=final_optimizer, loss='mean_squared_error')

# Ensure batch size is an integer
batch_size = int(best_params[0])  # Convert to integer

# Train the final autoencoder with early stopping and learning rate reduction
history = final_autoencoder.fit(X_tfidf, X_tfidf,
                                epochs=100,  # Increased epochs for more training
                                batch_size=batch_size,  # Use best-found batch size
                                validation_split=0.2,
                                verbose=1)

# Plot the training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Final Autoencoder Loss During Training')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# Predict the reconstructed data using the trained autoencoder
reconstructed_data = final_autoencoder.predict(X_tfidf)

# Calculate the reconstruction error (mean squared error for each sample)
reconstruction_error = np.mean(np.square(X_tfidf - reconstructed_data), axis=1)

# Calculate the average reconstruction error for the training set
average_reconstruction_error_train = np.mean(reconstruction_error)

# Display the average reconstruction error
print(f"Average Reconstruction Error (Training Set): {average_reconstruction_error_train}")

# Plot reconstruction error for each sample
plt.figure(figsize=(10, 6))
plt.plot(reconstruction_error, label='Reconstruction Error', color='red')
plt.title('Reconstruction Error for Each Sample')
plt.xlabel('Sample Index')
plt.ylabel('Reconstruction Error')
plt.grid(True)
plt.show()
# Out:
# Epoch 1/100
# 56/56 [==============================] - 1s 7ms/step - loss: 0.9646 - val_loss: 0.0127
# Epoch 2/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0010
# Epoch 3/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.7153e-04 - val_loss: 9.6707e-04
# Epoch 4/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.6403e-04 - val_loss: 9.6695e-04
# Epoch 5/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.6401e-04 - val_loss: 9.6695e-04
# Epoch 6/100
# 56/56 [==============================] - 1s 11ms/step - loss: 9.6401e-04 - val_loss: 9.6695e-04
# Epoch 7/100
# 56/56 [==============================] - 1s 11ms/step - loss: 9.6401e-04 - val_loss: 9.6695e-04
# Epoch 8/100
# 56/56 [==============================] - 1s 12ms/step - loss: 9.6402e-04 - val_loss: 9.6695e-04
# Epoch 9/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.6403e-04 - val_loss: 9.6696e-04
# Epoch 10/100
# 56/56 [==============================] - 0s 9ms/step - loss: 9.6406e-04 - val_loss: 9.6701e-04
# Epoch 11/100
# 56/56 [==============================] - 0s 9ms/step - loss: 9.6406e-04 - val_loss: 9.6704e-04
# Epoch 12/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.6416e-04 - val_loss: 9.6723e-04
# Epoch 13/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.6435e-04 - val_loss: 9.6738e-04
# Epoch 14/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.6444e-04 - val_loss: 9.6758e-04
# Epoch 15/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.6471e-04 - val_loss: 9.6803e-04
# Epoch 16/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.6757e-04 - val_loss: 9.7394e-04
# Epoch 17/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.7064e-04 - val_loss: 9.7445e-04
# Epoch 18/100
# 56/56 [==============================] - 0s 8ms/step - loss: 9.7074e-04 - val_loss: 9.7504e-04
# Epoch 19/100
# 56/56 [==============================] - 0s 7ms/step - loss: 9.7189e-04 - val_loss: 9.7543e-04
# Epoch 20/100
# 56/56 [==============================] - 1s 9ms/step - loss: 9.7325e-04 - val_loss: 9.7862e-04
# Epoch 21/100
# 56/56 [==============================] - 1s 10ms/step - loss: 9.7703e-04 - val_loss: 9.8167e-04
# Epoch 22/100
# 56/56 [==============================] - 1s 10ms/step - loss: 9.8288e-04 - val_loss: 9.9511e-04
# Epoch 23/100
# 56/56 [==============================] - 1s 10ms/step - loss: 9.9267e-04 - val_loss: 0.0010
# Epoch 24/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 25/100
# 56/56 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 26/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 27/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 28/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 29/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 30/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 31/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 32/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 33/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 34/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 35/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 36/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 37/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 38/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 39/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 40/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 41/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 42/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 43/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 44/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 45/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 46/100
# 56/56 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 47/100
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 48/100
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 49/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 50/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 51/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 52/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 53/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 54/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 55/100
# 56/56 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 56/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 57/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 58/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 59/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 60/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 61/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 62/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 63/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 64/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 65/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 66/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 67/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 68/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 69/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 70/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 71/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 72/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 73/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 74/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 75/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 76/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 77/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 78/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 79/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 80/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 81/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 82/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 83/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 84/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 85/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 86/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 87/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 88/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 89/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 90/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 91/100
# 56/56 [==============================] - 1s 13ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 92/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 93/100
# 56/56 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 94/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 95/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 96/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 97/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 98/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 99/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 100/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 0.0011
# 187/187 [==============================] - 0s 1ms/step
# Average Reconstruction Error (Training Set): 0.0009645965852025446
